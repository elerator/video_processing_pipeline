# %%
#from python_scripts.MPI_Data_Processing.mot import *
from mot import *
from os.path import basename
import os

vid = "./RPS_05_PS_C2.wmv"
outfile = "./motion_vectors_brocks2.hdf5"
# Out:
# Brocks dense optical flow not available

# %%
motob = ComputeMotion(vid,outfile,algorithm='brocks', scaled_size = (480,270), output_scaling = .25)
motob.to_file()
# Out:
# Estimated time to compute 30020 pairs: 23888.04168820381 s
# 30020
# ## Completed 0.02664890073284477% ##
# ## Current frame8.0 ##
# Estimated time to compute 30020 pairs: 24866.732621192932 s
# 30020
# ## Completed 0.05329780146568954% ##
# ## Current frame16.0 ##
# Estimated time to compute 30020 pairs: 22696.15549325943 s
# 30020
# ## Completed 0.07994670219853431% ##
# ## Current frame24.0 ##
# Estimated time to compute 30020 pairs: 22053.1082457304 s
# 30020
# ## Completed 0.10659560293137908% ##
# ## Current frame32.0 ##
# Estimated time to compute 30020 pairs: 26032.719138264656 s
# 30020
# ## Completed 0.13324450366422386% ##
# ## Current frame40.0 ##
# Estimated time to compute 30020 pairs: 24750.52538573742 s
# 30020
# ## Completed 0.15989340439706862% ##
# ## Current frame48.0 ##
# Estimated time to compute 30020 pairs: 23207.06508755684 s
# 30020
# ## Completed 0.1865423051299134% ##
# ## Current frame56.0 ##
# Estimated time to compute 30020 pairs: 26168.132162690163 s
# 30020
# ## Completed 0.21319120586275817% ##
# ## Current frame64.0 ##
# Estimated time to compute 30020 pairs: 25051.010497808456 s
# 30020
# ## Completed 0.23984010659560293% ##
# ## Current frame72.0 ##
# Estimated time to compute 30020 pairs: 32544.310954213142 s
# 30020
# ## Completed 0.2664890073284477% ##
# ## Current frame80.0 ##
# Estimated time to compute 30020 pairs: 25838.6410933733 s
# 30020
# ## Completed 0.2931379080612925% ##
# ## Current frame88.0 ##
# Estimated time to compute 30020 pairs: 23177.727209329605 s
# 30020
# ## Completed 0.31978680879413723% ##
# ## Current frame96.0 ##
# Estimated time to compute 30020 pairs: 23242.177138328552 s
# 30020
# ## Completed 0.3331112591605596% ##
# ## Current frame100.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 23748.246591091156 s
# 30020
# ## Completed 0.35976015989340443% ##
# ## Current frame108.0 ##
# Estimated time to compute 30020 pairs: 20980.625032186508 s
# 30020
# ## Completed 0.3864090606262492% ##
# ## Current frame116.0 ##
# Estimated time to compute 30020 pairs: 21882.753157019615 s
# 30020
# ## Completed 0.4130579613590939% ##
# ## Current frame124.0 ##
# Estimated time to compute 30020 pairs: 20224.398097991943 s
# 30020
# ## Completed 0.43970686209193866% ##
# ## Current frame132.0 ##
# Estimated time to compute 30020 pairs: 21754.4956690073 s
# 30020
# ## Completed 0.4663557628247834% ##
# ## Current frame140.0 ##
# Estimated time to compute 30020 pairs: 22418.13901603222 s
# 30020
# ## Completed 0.49300466355762823% ##
# ## Current frame148.0 ##
# Estimated time to compute 30020 pairs: 21675.37053823471 s
# 30020
# ## Completed 0.5196535642904729% ##
# ## Current frame156.0 ##
# Estimated time to compute 30020 pairs: 22625.42590558529 s
# 30020
# ## Completed 0.5463024650233178% ##
# ## Current frame164.0 ##
# Estimated time to compute 30020 pairs: 22419.956082105637 s
# 30020
# ## Completed 0.5729513657561626% ##
# ## Current frame172.0 ##
# Estimated time to compute 30020 pairs: 21925.424238443375 s
# 30020
# ## Completed 0.5996002664890073% ##
# ## Current frame180.0 ##
# Estimated time to compute 30020 pairs: 20972.166862487793 s
# 30020
# ## Completed 0.6262491672218521% ##
# ## Current frame188.0 ##
# Estimated time to compute 30020 pairs: 21953.9649695158 s
# 30020
# ## Completed 0.6528980679546968% ##
# ## Current frame196.0 ##
# Estimated time to compute 30020 pairs: 20936.550220251083 s
# 30020
# ## Completed 0.6662225183211192% ##
# ## Current frame200.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 23230.372918844223 s
# 30020
# ## Completed 0.692871419053964% ##
# ## Current frame208.0 ##
# Estimated time to compute 30020 pairs: 20696.309213638306 s
# 30020
# ## Completed 0.7195203197868089% ##
# ## Current frame216.0 ##
# Estimated time to compute 30020 pairs: 21919.217047691345 s
# 30020
# ## Completed 0.7461692205196536% ##
# ## Current frame224.0 ##
# Estimated time to compute 30020 pairs: 23079.509912133217 s
# 30020
# ## Completed 0.7728181212524984% ##
# ## Current frame232.0 ##
# Estimated time to compute 30020 pairs: 20164.53243613243 s
# 30020
# ## Completed 0.7994670219853431% ##
# ## Current frame240.0 ##
# Estimated time to compute 30020 pairs: 22058.99335682392 s
# 30020
# ## Completed 0.8261159227181878% ##
# ## Current frame248.0 ##
# Estimated time to compute 30020 pairs: 26549.785822033882 s
# 30020
# ## Completed 0.8527648234510327% ##
# ## Current frame256.0 ##
# Estimated time to compute 30020 pairs: 30003.540834784508 s
# 30020
# ## Completed 0.8794137241838773% ##
# ## Current frame264.0 ##
# Estimated time to compute 30020 pairs: 24383.061124682426 s
# 30020
# ## Completed 0.9060626249167222% ##
# ## Current frame272.0 ##
# Estimated time to compute 30020 pairs: 22398.616515398026 s
# 30020
# ## Completed 0.9327115256495668% ##
# ## Current frame280.0 ##
# Estimated time to compute 30020 pairs: 23357.92183160782 s
# 30020
# ## Completed 0.9593604263824117% ##
# ## Current frame288.0 ##
# Estimated time to compute 30020 pairs: 23657.034526467323 s
# 30020
# ## Completed 0.9860093271152565% ##
# ## Current frame296.0 ##
# Estimated time to compute 30020 pairs: 26150.901795625687 s
# 30020
# ## Completed 0.9993337774816788% ##
# ## Current frame300.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 23484.493769407272 s
# 30020
# ## Completed 1.0259826782145236% ##
# ## Current frame308.0 ##
# Estimated time to compute 30020 pairs: 28261.2482380867 s
# 30020
# ## Completed 1.0526315789473684% ##
# ## Current frame316.0 ##
# Estimated time to compute 30020 pairs: 27013.76393675804 s
# 30020
# ## Completed 1.0792804796802133% ##
# ## Current frame324.0 ##
# Estimated time to compute 30020 pairs: 27828.1235653162 s
# 30020
# ## Completed 1.1059293804130579% ##
# ## Current frame332.0 ##
# Estimated time to compute 30020 pairs: 29266.91334247589 s
# 30020
# ## Completed 1.1325782811459029% ##
# ## Current frame340.0 ##
# Estimated time to compute 30020 pairs: 28459.859554171562 s
# 30020
# ## Completed 1.1592271818787474% ##
# ## Current frame348.0 ##
# Estimated time to compute 30020 pairs: 29412.15069115162 s
# 30020
# ## Completed 1.1858760826115924% ##
# ## Current frame356.0 ##
# Estimated time to compute 30020 pairs: 27783.33481013775 s
# 30020
# ## Completed 1.212524983344437% ##
# ## Current frame364.0 ##
# Estimated time to compute 30020 pairs: 20958.164449334145 s
# 30020
# ## Completed 1.239173884077282% ##
# ## Current frame372.0 ##
# Estimated time to compute 30020 pairs: 28369.39274609089 s
# 30020
# ## Completed 1.2658227848101267% ##
# ## Current frame380.0 ##
# Estimated time to compute 30020 pairs: 32316.320605278015 s
# 30020
# ## Completed 1.2924716855429714% ##
# ## Current frame388.0 ##
# Estimated time to compute 30020 pairs: 29652.848871946335 s
# 30020
# ## Completed 1.3191205862758162% ##
# ## Current frame396.0 ##
# Estimated time to compute 30020 pairs: 32107.850967645645 s
# 30020
# ## Completed 1.3324450366422385% ##
# ## Current frame400.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 44930.240299105644 s
# 30020
# ## Completed 1.3590939373750832% ##
# ## Current frame408.0 ##
# Estimated time to compute 30020 pairs: 35482.27149784565 s
# 30020
# ## Completed 1.385742838107928% ##
# ## Current frame416.0 ##
# Estimated time to compute 30020 pairs: 26525.241562724113 s
# 30020
# ## Completed 1.4123917388407727% ##
# ## Current frame424.0 ##
# Estimated time to compute 30020 pairs: 34702.553325891495 s
# 30020
# ## Completed 1.4390406395736177% ##
# ## Current frame432.0 ##
# Estimated time to compute 30020 pairs: 25016.93894326687 s
# 30020
# ## Completed 1.4656895403064623% ##
# ## Current frame440.0 ##
# Estimated time to compute 30020 pairs: 24170.91620028019 s
# 30020
# ## Completed 1.4923384410393072% ##
# ## Current frame448.0 ##
# Estimated time to compute 30020 pairs: 26631.33818089962 s
# 30020
# ## Completed 1.5189873417721518% ##
# ## Current frame456.0 ##
# Estimated time to compute 30020 pairs: 25022.510026693344 s
# 30020
# ## Completed 1.5456362425049968% ##
# ## Current frame464.0 ##
# Estimated time to compute 30020 pairs: 24990.687661767006 s
# 30020
# ## Completed 1.5722851432378413% ##
# ## Current frame472.0 ##
# Estimated time to compute 30020 pairs: 25904.80251789093 s
# 30020
# ## Completed 1.5989340439706863% ##
# ## Current frame480.0 ##
# Estimated time to compute 30020 pairs: 25302.161952853203 s
# 30020
# ## Completed 1.625582944703531% ##
# ## Current frame488.0 ##
# Estimated time to compute 30020 pairs: 21942.619713544846 s
# 30020
# ## Completed 1.6522318454363756% ##
# ## Current frame496.0 ##
# Estimated time to compute 30020 pairs: 25916.61031603813 s
# 30020
# ## Completed 1.6655562958027983% ##
# ## Current frame500.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 26739.89602446556 s
# 30020
# ## Completed 1.692205196535643% ##
# ## Current frame508.0 ##
# Estimated time to compute 30020 pairs: 24755.671502947807 s
# 30020
# ## Completed 1.7188540972684876% ##
# ## Current frame516.0 ##
# Estimated time to compute 30020 pairs: 23152.85550236702 s
# 30020
# ## Completed 1.7455029980013324% ##
# ## Current frame524.0 ##
# Estimated time to compute 30020 pairs: 23457.125945091248 s
# 30020
# ## Completed 1.7721518987341773% ##
# ## Current frame532.0 ##
# Estimated time to compute 30020 pairs: 26596.25654876232 s
# 30020
# ## Completed 1.798800799467022% ##
# ## Current frame540.0 ##
# Estimated time to compute 30020 pairs: 24354.9212038517 s
# 30020
# ## Completed 1.8254497001998666% ##
# ## Current frame548.0 ##
# Estimated time to compute 30020 pairs: 25212.105796337128 s
# 30020
# ## Completed 1.8520986009327116% ##
# ## Current frame556.0 ##
# Estimated time to compute 30020 pairs: 21482.971780896187 s
# 30020
# ## Completed 1.8787475016655564% ##
# ## Current frame564.0 ##
# Estimated time to compute 30020 pairs: 23703.107126951218 s
# 30020
# ## Completed 1.9053964023984011% ##
# ## Current frame572.0 ##
# Estimated time to compute 30020 pairs: 26200.423332452774 s
# 30020
# ## Completed 1.9320453031312457% ##
# ## Current frame580.0 ##
# Estimated time to compute 30020 pairs: 21753.62605392933 s
# 30020
# ## Completed 1.9586942038640907% ##
# ## Current frame588.0 ##
# Estimated time to compute 30020 pairs: 22284.581528306007 s
# 30020
# ## Completed 1.9853431045969354% ##
# ## Current frame596.0 ##
# Estimated time to compute 30020 pairs: 23876.101479530334 s
# 30020
# ## Completed 1.9986675549633577% ##
# ## Current frame600.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 25633.810955882072 s
# 30020
# ## Completed 2.0253164556962027% ##
# ## Current frame608.0 ##
# Estimated time to compute 30020 pairs: 18350.843725800514 s
# 30020
# ## Completed 2.051965356429047% ##
# ## Current frame616.0 ##
# Estimated time to compute 30020 pairs: 21638.58546257019 s
# 30020
# ## Completed 2.0786142571618917% ##
# ## Current frame624.0 ##
# Estimated time to compute 30020 pairs: 22523.76861870289 s
# 30020
# ## Completed 2.1052631578947367% ##
# ## Current frame632.0 ##
# Estimated time to compute 30020 pairs: 22518.210060596466 s
# 30020
# ## Completed 2.1319120586275817% ##
# ## Current frame640.0 ##
# Estimated time to compute 30020 pairs: 27986.075008511543 s
# 30020
# ## Completed 2.1585609593604267% ##
# ## Current frame648.0 ##
# Estimated time to compute 30020 pairs: 22785.36171734333 s
# 30020
# ## Completed 2.1852098600932712% ##
# ## Current frame656.0 ##
# Estimated time to compute 30020 pairs: 21960.152477622032 s
# 30020
# ## Completed 2.2118587608261158% ##
# ## Current frame664.0 ##
# Estimated time to compute 30020 pairs: 20805.231186151505 s
# 30020
# ## Completed 2.2385076615589607% ##
# ## Current frame672.0 ##
# Estimated time to compute 30020 pairs: 24386.158457398415 s
# 30020
# ## Completed 2.2651565622918057% ##
# ## Current frame680.0 ##
# Estimated time to compute 30020 pairs: 22737.129393815994 s
# 30020
# ## Completed 2.2918054630246503% ##
# ## Current frame688.0 ##
# Estimated time to compute 30020 pairs: 23872.092482447624 s
# 30020
# ## Completed 2.318454363757495% ##
# ## Current frame696.0 ##
# Estimated time to compute 30020 pairs: 27405.525529384613 s
# 30020
# ## Completed 2.331778814123917% ##
# ## Current frame700.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 21898.29886853695 s
# 30020
# ## Completed 2.358427714856762% ##
# ## Current frame708.0 ##
# Estimated time to compute 30020 pairs: 24610.618455410004 s
# 30020
# ## Completed 2.385076615589607% ##
# ## Current frame716.0 ##
# Estimated time to compute 30020 pairs: 24186.95666193962 s
# 30020
# ## Completed 2.4117255163224516% ##
# ## Current frame724.0 ##
# Estimated time to compute 30020 pairs: 24922.928364276886 s
# 30020
# ## Completed 2.438374417055296% ##
# ## Current frame732.0 ##
# Estimated time to compute 30020 pairs: 25388.65018248558 s
# 30020
# ## Completed 2.465023317788141% ##
# ## Current frame740.0 ##
# Estimated time to compute 30020 pairs: 25339.299526810646 s
# 30020
# ## Completed 2.491672218520986% ##
# ## Current frame748.0 ##
# Estimated time to compute 30020 pairs: 24963.560502529144 s
# 30020
# ## Completed 2.518321119253831% ##
# ## Current frame756.0 ##
# Estimated time to compute 30020 pairs: 21710.049570798874 s
# 30020
# ## Completed 2.5449700199866756% ##
# ## Current frame764.0 ##
# Estimated time to compute 30020 pairs: 22355.23596405983 s
# 30020
# ## Completed 2.57161892071952% ##
# ## Current frame772.0 ##
# Estimated time to compute 30020 pairs: 24700.542201399803 s
# 30020
# ## Completed 2.598267821452365% ##
# ## Current frame780.0 ##
# Estimated time to compute 30020 pairs: 32892.810091376305 s
# 30020
# ## Completed 2.62491672218521% ##
# ## Current frame788.0 ##
# Estimated time to compute 30020 pairs: 31721.587095856667 s
# 30020
# ## Completed 2.6515656229180546% ##
# ## Current frame796.0 ##
# Estimated time to compute 30020 pairs: 31978.255059719086 s
# 30020
# ## Completed 2.664890073284477% ##
# ## Current frame800.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 18306.183802485466 s
# 30020
# ## Completed 2.691538974017322% ##
# ## Current frame808.0 ##
# Estimated time to compute 30020 pairs: 34880.75552761555 s
# 30020
# ## Completed 2.7181878747501664% ##
# ## Current frame816.0 ##
# Estimated time to compute 30020 pairs: 28373.255017995834 s
# 30020
# ## Completed 2.7448367754830114% ##
# ## Current frame824.0 ##
# Estimated time to compute 30020 pairs: 24568.141516447067 s
# 30020
# ## Completed 2.771485676215856% ##
# ## Current frame832.0 ##
# Estimated time to compute 30020 pairs: 24455.54067850113 s
# 30020
# ## Completed 2.798134576948701% ##
# ## Current frame840.0 ##
# Estimated time to compute 30020 pairs: 23010.53386926651 s
# 30020
# ## Completed 2.8247834776815455% ##
# ## Current frame848.0 ##
# Estimated time to compute 30020 pairs: 25915.733543634415 s
# 30020
# ## Completed 2.8514323784143905% ##
# ## Current frame856.0 ##
# Estimated time to compute 30020 pairs: 23371.071628332138 s
# 30020
# ## Completed 2.8780812791472354% ##
# ## Current frame864.0 ##
# Estimated time to compute 30020 pairs: 25274.15981054306 s
# 30020
# ## Completed 2.90473017988008% ##
# ## Current frame872.0 ##
# Estimated time to compute 30020 pairs: 21320.326026678085 s
# 30020
# ## Completed 2.9313790806129245% ##
# ## Current frame880.0 ##
# Estimated time to compute 30020 pairs: 22464.942558407784 s
# 30020
# ## Completed 2.9580279813457695% ##
# ## Current frame888.0 ##
# Estimated time to compute 30020 pairs: 21410.673844218254 s
# 30020
# ## Completed 2.9846768820786145% ##
# ## Current frame896.0 ##
# Estimated time to compute 30020 pairs: 23759.963133335114 s
# 30020
# ## Completed 2.9980013324450367% ##
# ## Current frame900.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 21984.02215898037 s
# 30020
# ## Completed 3.0246502331778813% ##
# ## Current frame908.0 ##
# Estimated time to compute 30020 pairs: 22527.915394306183 s
# 30020
# ## Completed 3.0512991339107263% ##
# ## Current frame916.0 ##
# Estimated time to compute 30020 pairs: 24353.634674549103 s
# 30020
# ## Completed 3.077948034643571% ##
# ## Current frame924.0 ##
# Estimated time to compute 30020 pairs: 22808.62034201622 s
# 30020
# ## Completed 3.104596935376416% ##
# ## Current frame932.0 ##
# Estimated time to compute 30020 pairs: 20349.104657769203 s
# 30020
# ## Completed 3.1312458361092603% ##
# ## Current frame940.0 ##
# Estimated time to compute 30020 pairs: 23630.049619078636 s
# 30020
# ## Completed 3.1578947368421053% ##
# ## Current frame948.0 ##
# Estimated time to compute 30020 pairs: 22250.88215470314 s
# 30020
# ## Completed 3.18454363757495% ##
# ## Current frame956.0 ##
# Estimated time to compute 30020 pairs: 22979.50417816639 s
# 30020
# ## Completed 3.2111925383077953% ##
# ## Current frame964.0 ##
# Estimated time to compute 30020 pairs: 22432.69433259964 s
# 30020
# ## Completed 3.23784143904064% ##
# ## Current frame972.0 ##
# Estimated time to compute 30020 pairs: 21408.534698486328 s
# 30020
# ## Completed 3.264490339773484% ##
# ## Current frame980.0 ##
# Estimated time to compute 30020 pairs: 26104.89629507065 s
# 30020
# ## Completed 3.2911392405063293% ##
# ## Current frame988.0 ##
# Estimated time to compute 30020 pairs: 23752.624190449715 s
# 30020
# ## Completed 3.317788141239174% ##
# ## Current frame996.0 ##
# Estimated time to compute 30020 pairs: 26071.734615564346 s
# 30020
# ## Completed 3.3311125916055966% ##
# ## Current frame1000.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 23937.51580774784 s
# 30020
# ## Completed 3.357761492338441% ##
# ## Current frame1008.0 ##
# Estimated time to compute 30020 pairs: 23393.03477704525 s
# 30020
# ## Completed 3.384410393071286% ##
# ## Current frame1016.0 ##
# Estimated time to compute 30020 pairs: 20866.59004509449 s
# 30020
# ## Completed 3.4110592938041306% ##
# ## Current frame1024.0 ##
# Estimated time to compute 30020 pairs: 22602.38557934761 s
# 30020
# ## Completed 3.437708194536975% ##
# ## Current frame1032.0 ##
# Estimated time to compute 30020 pairs: 23504.771367907524 s
# 30020
# ## Completed 3.46435709526982% ##
# ## Current frame1040.0 ##
# Estimated time to compute 30020 pairs: 21654.66797351837 s
# 30020
# ## Completed 3.4910059960026647% ##
# ## Current frame1048.0 ##
# Estimated time to compute 30020 pairs: 22116.815602183342 s
# 30020
# ## Completed 3.5176548967355092% ##
# ## Current frame1056.0 ##
# Estimated time to compute 30020 pairs: 21192.41924762726 s
# 30020
# ## Completed 3.5443037974683547% ##
# ## Current frame1064.0 ##
# Estimated time to compute 30020 pairs: 22707.746782302856 s
# 30020
# ## Completed 3.570952698201199% ##
# ## Current frame1072.0 ##
# Estimated time to compute 30020 pairs: 22342.98441171646 s
# 30020
# ## Completed 3.597601598934044% ##
# ## Current frame1080.0 ##
# Estimated time to compute 30020 pairs: 26462.69011437893 s
# 30020
# ## Completed 3.6242504996668887% ##
# ## Current frame1088.0 ##
# Estimated time to compute 30020 pairs: 24157.972176671028 s
# 30020
# ## Completed 3.6508994003997333% ##
# ## Current frame1096.0 ##
# Estimated time to compute 30020 pairs: 24594.535944461823 s
# 30020
# ## Completed 3.664223850766156% ##
# ## Current frame1100.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 26149.151829481125 s
# 30020
# ## Completed 3.6908727514990005% ##
# ## Current frame1108.0 ##
# Estimated time to compute 30020 pairs: 20440.098423957825 s
# 30020
# ## Completed 3.7175216522318455% ##
# ## Current frame1116.0 ##
# Estimated time to compute 30020 pairs: 20015.411343574524 s
# 30020
# ## Completed 3.74417055296469% ##
# ## Current frame1124.0 ##
# Estimated time to compute 30020 pairs: 21559.3663918972 s
# 30020
# ## Completed 3.7708194536975346% ##
# ## Current frame1132.0 ##
# Estimated time to compute 30020 pairs: 24589.152740836143 s
# 30020
# ## Completed 3.79746835443038% ##
# ## Current frame1140.0 ##
# Estimated time to compute 30020 pairs: 23903.52477312088 s
# 30020
# ## Completed 3.8241172551632245% ##
# ## Current frame1148.0 ##
# Estimated time to compute 30020 pairs: 26541.352702975273 s
# 30020
# ## Completed 3.8507661558960695% ##
# ## Current frame1156.0 ##
# Estimated time to compute 30020 pairs: 22494.080926179886 s
# 30020
# ## Completed 3.877415056628914% ##
# ## Current frame1164.0 ##
# Estimated time to compute 30020 pairs: 21589.818128943443 s
# 30020
# ## Completed 3.9040639573617586% ##
# ## Current frame1172.0 ##
# Estimated time to compute 30020 pairs: 23511.042974591255 s
# 30020
# ## Completed 3.930712858094604% ##
# ## Current frame1180.0 ##
# Estimated time to compute 30020 pairs: 23137.65244781971 s
# 30020
# ## Completed 3.957361758827448% ##
# ## Current frame1188.0 ##
# Estimated time to compute 30020 pairs: 25583.27665746212 s
# 30020
# ## Completed 3.9840106595602927% ##
# ## Current frame1196.0 ##
# Estimated time to compute 30020 pairs: 25964.512507915497 s
# 30020
# ## Completed 3.9973351099267154% ##
# ## Current frame1200.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 25344.948446154594 s
# 30020
# ## Completed 4.023984010659561% ##
# ## Current frame1208.0 ##
# Estimated time to compute 30020 pairs: 37246.29731416702 s
# 30020
# ## Completed 4.050632911392405% ##
# ## Current frame1216.0 ##
# Estimated time to compute 30020 pairs: 32270.11738359928 s
# 30020
# ## Completed 4.07728181212525% ##
# ## Current frame1224.0 ##
# Estimated time to compute 30020 pairs: 20171.12164914608 s
# 30020
# ## Completed 4.103930712858094% ##
# ## Current frame1232.0 ##
# Estimated time to compute 30020 pairs: 27965.68647146225 s
# 30020
# ## Completed 4.130579613590939% ##
# ## Current frame1240.0 ##
# Estimated time to compute 30020 pairs: 18705.79429745674 s
# 30020
# ## Completed 4.1572285143237835% ##
# ## Current frame1248.0 ##
# Estimated time to compute 30020 pairs: 22084.853669404984 s
# 30020
# ## Completed 4.183877415056629% ##
# ## Current frame1256.0 ##
# Estimated time to compute 30020 pairs: 22217.520964741707 s
# 30020
# ## Completed 4.2105263157894735% ##
# ## Current frame1264.0 ##
# Estimated time to compute 30020 pairs: 21049.248576760292 s
# 30020
# ## Completed 4.237175216522319% ##
# ## Current frame1272.0 ##
# Estimated time to compute 30020 pairs: 23727.085062861443 s
# 30020
# ## Completed 4.263824117255163% ##
# ## Current frame1280.0 ##
# Estimated time to compute 30020 pairs: 23024.03795361519 s
# 30020
# ## Completed 4.290473017988008% ##
# ## Current frame1288.0 ##
# Estimated time to compute 30020 pairs: 22823.6883020401 s
# 30020
# ## Completed 4.317121918720853% ##
# ## Current frame1296.0 ##
# Estimated time to compute 30020 pairs: 20427.05777645111 s
# 30020
# ## Completed 4.330446369087275% ##
# ## Current frame1300.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 22321.473963856697 s
# 30020
# ## Completed 4.35709526982012% ##
# ## Current frame1308.0 ##
# Estimated time to compute 30020 pairs: 20734.59106504917 s
# 30020
# ## Completed 4.383744170552965% ##
# ## Current frame1316.0 ##
# Estimated time to compute 30020 pairs: 22251.84213101864 s
# 30020
# ## Completed 4.410393071285809% ##
# ## Current frame1324.0 ##
# Estimated time to compute 30020 pairs: 22612.684076428413 s
# 30020
# ## Completed 4.437041972018655% ##
# ## Current frame1332.0 ##
# Estimated time to compute 30020 pairs: 21291.91054880619 s
# 30020
# ## Completed 4.463690872751499% ##
# ## Current frame1340.0 ##
# Estimated time to compute 30020 pairs: 21764.150901436806 s
# 30020
# ## Completed 4.490339773484344% ##
# ## Current frame1348.0 ##
# Estimated time to compute 30020 pairs: 23908.652997016907 s
# 30020
# ## Completed 4.516988674217188% ##
# ## Current frame1356.0 ##
# Estimated time to compute 30020 pairs: 22047.01288819313 s
# 30020
# ## Completed 4.543637574950033% ##
# ## Current frame1364.0 ##
# Estimated time to compute 30020 pairs: 22615.182877779007 s
# 30020
# ## Completed 4.570286475682878% ##
# ## Current frame1372.0 ##
# Estimated time to compute 30020 pairs: 20281.990414261818 s
# 30020
# ## Completed 4.596935376415723% ##
# ## Current frame1380.0 ##
# Estimated time to compute 30020 pairs: 24241.537533402443 s
# 30020
# ## Completed 4.623584277148567% ##
# ## Current frame1388.0 ##
# Estimated time to compute 30020 pairs: 21142.140823602676 s
# 30020
# ## Completed 4.650233177881413% ##
# ## Current frame1396.0 ##
# Estimated time to compute 30020 pairs: 24600.67335128784 s
# 30020
# ## Completed 4.663557628247834% ##
# ## Current frame1400.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 24296.477165818214 s
# 30020
# ## Completed 4.69020652898068% ##
# ## Current frame1408.0 ##
# Estimated time to compute 30020 pairs: 22867.52871155739 s
# 30020
# ## Completed 4.716855429713524% ##
# ## Current frame1416.0 ##
# Estimated time to compute 30020 pairs: 22335.598946213722 s
# 30020
# ## Completed 4.7435043304463695% ##
# ## Current frame1424.0 ##
# Estimated time to compute 30020 pairs: 21781.97353720665 s
# 30020
# ## Completed 4.770153231179214% ##
# ## Current frame1432.0 ##
# Estimated time to compute 30020 pairs: 20053.90791475773 s
# 30020
# ## Completed 4.796802131912059% ##
# ## Current frame1440.0 ##
# Estimated time to compute 30020 pairs: 21104.793003201485 s
# 30020
# ## Completed 4.823451032644903% ##
# ## Current frame1448.0 ##
# Estimated time to compute 30020 pairs: 20005.39198219776 s
# 30020
# ## Completed 4.850099933377748% ##
# ## Current frame1456.0 ##
# Estimated time to compute 30020 pairs: 20413.0571526289 s
# 30020
# ## Completed 4.876748834110592% ##
# ## Current frame1464.0 ##
# Estimated time to compute 30020 pairs: 21576.215631365776 s
# 30020
# ## Completed 4.903397734843438% ##
# ## Current frame1472.0 ##
# Estimated time to compute 30020 pairs: 21699.133754372597 s
# 30020
# ## Completed 4.930046635576282% ##
# ## Current frame1480.0 ##
# Estimated time to compute 30020 pairs: 21343.440610170364 s
# 30020
# ## Completed 4.956695536309128% ##
# ## Current frame1488.0 ##
# Estimated time to compute 30020 pairs: 21943.19498360157 s
# 30020
# ## Completed 4.983344437041972% ##
# ## Current frame1496.0 ##
# Estimated time to compute 30020 pairs: 20863.243100643158 s
# 30020
# ## Completed 4.996668887408394% ##
# ## Current frame1500.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 22520.09422659874 s
# 30020
# ## Completed 5.023317788141239% ##
# ## Current frame1508.0 ##
# Estimated time to compute 30020 pairs: 22033.710998296738 s
# 30020
# ## Completed 5.0499666888740835% ##
# ## Current frame1516.0 ##
# Estimated time to compute 30020 pairs: 21399.72850382328 s
# 30020
# ## Completed 5.076615589606929% ##
# ## Current frame1524.0 ##
# Estimated time to compute 30020 pairs: 21429.798218607903 s
# 30020
# ## Completed 5.1032644903397735% ##
# ## Current frame1532.0 ##
# Estimated time to compute 30020 pairs: 22435.070564746857 s
# 30020
# ## Completed 5.129913391072619% ##
# ## Current frame1540.0 ##
# Estimated time to compute 30020 pairs: 21620.71451485157 s
# 30020
# ## Completed 5.156562291805463% ##
# ## Current frame1548.0 ##
# Estimated time to compute 30020 pairs: 21295.967857837677 s
# 30020
# ## Completed 5.183211192538308% ##
# ## Current frame1556.0 ##
# Estimated time to compute 30020 pairs: 21138.261553049088 s
# 30020
# ## Completed 5.2098600932711525% ##
# ## Current frame1564.0 ##
# Estimated time to compute 30020 pairs: 21383.330175876617 s
# 30020
# ## Completed 5.236508994003997% ##
# ## Current frame1572.0 ##
# Estimated time to compute 30020 pairs: 25217.064928412437 s
# 30020
# ## Completed 5.263157894736842% ##
# ## Current frame1580.0 ##
# Estimated time to compute 30020 pairs: 23131.191172003746 s
# 30020
# ## Completed 5.289806795469687% ##
# ## Current frame1588.0 ##
# Estimated time to compute 30020 pairs: 24470.96739947796 s
# 30020
# ## Completed 5.3164556962025316% ##
# ## Current frame1596.0 ##
# Estimated time to compute 30020 pairs: 24690.719666481018 s
# 30020
# ## Completed 5.329780146568954% ##
# ## Current frame1600.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 23999.9768948555 s
# 30020
# ## Completed 5.356429047301798% ##
# ## Current frame1608.0 ##
# Estimated time to compute 30020 pairs: 22262.67742753029 s
# 30020
# ## Completed 5.383077948034644% ##
# ## Current frame1616.0 ##
# Estimated time to compute 30020 pairs: 23785.971960425377 s
# 30020
# ## Completed 5.409726848767488% ##
# ## Current frame1624.0 ##
# Estimated time to compute 30020 pairs: 21875.814129710197 s
# 30020
# ## Completed 5.436375749500333% ##
# ## Current frame1632.0 ##
# Estimated time to compute 30020 pairs: 21171.118151545525 s
# 30020
# ## Completed 5.463024650233178% ##
# ## Current frame1640.0 ##
# Estimated time to compute 30020 pairs: 22673.661807775497 s
# 30020
# ## Completed 5.489673550966023% ##
# ## Current frame1648.0 ##
# Estimated time to compute 30020 pairs: 19284.443506598473 s
# 30020
# ## Completed 5.516322451698867% ##
# ## Current frame1656.0 ##
# Estimated time to compute 30020 pairs: 21473.53126823902 s
# 30020
# ## Completed 5.542971352431712% ##
# ## Current frame1664.0 ##
# Estimated time to compute 30020 pairs: 22574.97838973999 s
# 30020
# ## Completed 5.5696202531645564% ##
# ## Current frame1672.0 ##
# Estimated time to compute 30020 pairs: 24747.980061769485 s
# 30020
# ## Completed 5.596269153897402% ##
# ## Current frame1680.0 ##
# Estimated time to compute 30020 pairs: 24833.818764090538 s
# 30020
# ## Completed 5.622918054630246% ##
# ## Current frame1688.0 ##
# Estimated time to compute 30020 pairs: 25581.72083377838 s
# 30020
# ## Completed 5.649566955363091% ##
# ## Current frame1696.0 ##
# Estimated time to compute 30020 pairs: 27715.124601125717 s
# 30020
# ## Completed 5.662891405729513% ##
# ## Current frame1700.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 22704.390891194344 s
# 30020
# ## Completed 5.689540306462358% ##
# ## Current frame1708.0 ##
# Estimated time to compute 30020 pairs: 21650.06760239601 s
# 30020
# ## Completed 5.716189207195203% ##
# ## Current frame1716.0 ##
# Estimated time to compute 30020 pairs: 21098.81663620472 s
# 30020
# ## Completed 5.742838107928048% ##
# ## Current frame1724.0 ##
# Estimated time to compute 30020 pairs: 22137.985182404518 s
# 30020
# ## Completed 5.769487008660893% ##
# ## Current frame1732.0 ##
# Estimated time to compute 30020 pairs: 21843.490751981735 s
# 30020
# ## Completed 5.796135909393738% ##
# ## Current frame1740.0 ##
# Estimated time to compute 30020 pairs: 21924.59309399128 s
# 30020
# ## Completed 5.822784810126582% ##
# ## Current frame1748.0 ##
# Estimated time to compute 30020 pairs: 22527.25960433483 s
# 30020
# ## Completed 5.849433710859428% ##
# ## Current frame1756.0 ##
# Estimated time to compute 30020 pairs: 24901.450124382973 s
# 30020
# ## Completed 5.876082611592272% ##
# ## Current frame1764.0 ##
# Estimated time to compute 30020 pairs: 24677.64323234558 s
# 30020
# ## Completed 5.902731512325117% ##
# ## Current frame1772.0 ##
# Estimated time to compute 30020 pairs: 29284.367375969887 s
# 30020
# ## Completed 5.929380413057961% ##
# ## Current frame1780.0 ##
# Estimated time to compute 30020 pairs: 25168.487263917923 s
# 30020
# ## Completed 5.956029313790806% ##
# ## Current frame1788.0 ##
# Estimated time to compute 30020 pairs: 29121.03093981743 s
# 30020
# ## Completed 5.982678214523651% ##
# ## Current frame1796.0 ##
# Estimated time to compute 30020 pairs: 30228.60025882721 s
# 30020
# ## Completed 5.9960026648900735% ##
# ## Current frame1800.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 28002.966297268867 s
# 30020
# ## Completed 6.022651565622918% ##
# ## Current frame1808.0 ##
# Estimated time to compute 30020 pairs: 25451.65164768696 s
# 30020
# ## Completed 6.049300466355763% ##
# ## Current frame1816.0 ##
# Estimated time to compute 30020 pairs: 28052.360791563988 s
# 30020
# ## Completed 6.075949367088607% ##
# ## Current frame1824.0 ##
# Estimated time to compute 30020 pairs: 26571.5414083004 s
# 30020
# ## Completed 6.1025982678214525% ##
# ## Current frame1832.0 ##
# Estimated time to compute 30020 pairs: 28414.09292936325 s
# 30020
# ## Completed 6.129247168554297% ##
# ## Current frame1840.0 ##
# Estimated time to compute 30020 pairs: 30806.268914341927 s
# 30020
# ## Completed 6.155896069287142% ##
# ## Current frame1848.0 ##
# Estimated time to compute 30020 pairs: 27431.623823046684 s
# 30020
# ## Completed 6.182544970019987% ##
# ## Current frame1856.0 ##
# Estimated time to compute 30020 pairs: 31685.859515070915 s
# 30020
# ## Completed 6.209193870752832% ##
# ## Current frame1864.0 ##
# Estimated time to compute 30020 pairs: 31455.282687544823 s
# 30020
# ## Completed 6.235842771485676% ##
# ## Current frame1872.0 ##
# Estimated time to compute 30020 pairs: 33238.074117302895 s
# 30020
# ## Completed 6.262491672218521% ##
# ## Current frame1880.0 ##
# Estimated time to compute 30020 pairs: 37258.75285029411 s
# 30020
# ## Completed 6.289140572951365% ##
# ## Current frame1888.0 ##
# Estimated time to compute 30020 pairs: 39249.706152677536 s
# 30020
# ## Completed 6.315789473684211% ##
# ## Current frame1896.0 ##
# Estimated time to compute 30020 pairs: 29822.434548139572 s
# 30020
# ## Completed 6.329113924050633% ##
# ## Current frame1900.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 28177.635464072227 s
# 30020
# ## Completed 6.355762824783477% ##
# ## Current frame1908.0 ##
# Estimated time to compute 30020 pairs: 25463.67327094078 s
# 30020
# ## Completed 6.382411725516322% ##
# ## Current frame1916.0 ##
# Estimated time to compute 30020 pairs: 22868.907391428947 s
# 30020
# ## Completed 6.409060626249167% ##
# ## Current frame1924.0 ##
# Estimated time to compute 30020 pairs: 21301.46557867527 s
# 30020
# ## Completed 6.435709526982011% ##
# ## Current frame1932.0 ##
# Estimated time to compute 30020 pairs: 22161.990852952003 s
# 30020
# ## Completed 6.4623584277148565% ##
# ## Current frame1940.0 ##
# Estimated time to compute 30020 pairs: 20493.40618610382 s
# 30020
# ## Completed 6.489007328447702% ##
# ## Current frame1948.0 ##
# Estimated time to compute 30020 pairs: 22378.742411136627 s
# 30020
# ## Completed 6.515656229180547% ##
# ## Current frame1956.0 ##
# Estimated time to compute 30020 pairs: 21028.583588004112 s
# 30020
# ## Completed 6.542305129913391% ##
# ## Current frame1964.0 ##
# Estimated time to compute 30020 pairs: 22223.518803715706 s
# 30020
# ## Completed 6.568954030646236% ##
# ## Current frame1972.0 ##
# Estimated time to compute 30020 pairs: 26468.00711274147 s
# 30020
# ## Completed 6.595602931379081% ##
# ## Current frame1980.0 ##
# Estimated time to compute 30020 pairs: 21955.58073580265 s
# 30020
# ## Completed 6.622251832111925% ##
# ## Current frame1988.0 ##
# Estimated time to compute 30020 pairs: 22520.61581671238 s
# 30020
# ## Completed 6.64890073284477% ##
# ## Current frame1996.0 ##
# Estimated time to compute 30020 pairs: 24238.88484954834 s
# 30020
# ## Completed 6.662225183211193% ##
# ## Current frame2000.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 22530.824847221375 s
# 30020
# ## Completed 6.688874083944037% ##
# ## Current frame2008.0 ##
# Estimated time to compute 30020 pairs: 22248.057695031166 s
# 30020
# ## Completed 6.715522984676882% ##
# ## Current frame2016.0 ##
# Estimated time to compute 30020 pairs: 21519.883899092674 s
# 30020
# ## Completed 6.742171885409727% ##
# ## Current frame2024.0 ##
# Estimated time to compute 30020 pairs: 17689.18206334114 s
# 30020
# ## Completed 6.768820786142572% ##
# ## Current frame2032.0 ##
# Estimated time to compute 30020 pairs: 26009.5562428236 s
# 30020
# ## Completed 6.795469686875416% ##
# ## Current frame2040.0 ##
# Estimated time to compute 30020 pairs: 23691.196442246437 s
# 30020
# ## Completed 6.822118587608261% ##
# ## Current frame2048.0 ##
# Estimated time to compute 30020 pairs: 23449.235888123512 s
# 30020
# ## Completed 6.848767488341107% ##
# ## Current frame2056.0 ##
# Estimated time to compute 30020 pairs: 24101.34609937668 s
# 30020
# ## Completed 6.87541638907395% ##
# ## Current frame2064.0 ##
# Estimated time to compute 30020 pairs: 22653.598929047585 s
# 30020
# ## Completed 6.902065289806796% ##
# ## Current frame2072.0 ##
# Estimated time to compute 30020 pairs: 23935.045635700226 s
# 30020
# ## Completed 6.92871419053964% ##
# ## Current frame2080.0 ##
# Estimated time to compute 30020 pairs: 22702.634662389755 s
# 30020
# ## Completed 6.955363091272485% ##
# ## Current frame2088.0 ##
# Estimated time to compute 30020 pairs: 22218.79049539566 s
# 30020
# ## Completed 6.982011992005329% ##
# ## Current frame2096.0 ##
# Estimated time to compute 30020 pairs: 24827.78782248497 s
# 30020
# ## Completed 6.995336442371753% ##
# ## Current frame2100.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 25127.39705681801 s
# 30020
# ## Completed 7.021985343104598% ##
# ## Current frame2108.0 ##
# Estimated time to compute 30020 pairs: 25110.017280578613 s
# 30020
# ## Completed 7.048634243837442% ##
# ## Current frame2116.0 ##
# Estimated time to compute 30020 pairs: 22083.902639746666 s
# 30020
# ## Completed 7.075283144570286% ##
# ## Current frame2124.0 ##
# Estimated time to compute 30020 pairs: 22921.636304855347 s
# 30020
# ## Completed 7.101932045303132% ##
# ## Current frame2132.0 ##
# Estimated time to compute 30020 pairs: 21726.9310182333 s
# 30020
# ## Completed 7.128580946035975% ##
# ## Current frame2140.0 ##
# Estimated time to compute 30020 pairs: 21968.578439354897 s
# 30020
# ## Completed 7.155229846768821% ##
# ## Current frame2148.0 ##
# Estimated time to compute 30020 pairs: 23529.510664343834 s
# 30020
# ## Completed 7.181878747501666% ##
# ## Current frame2156.0 ##
# Estimated time to compute 30020 pairs: 23638.398639559746 s
# 30020
# ## Completed 7.20852764823451% ##
# ## Current frame2164.0 ##
# Estimated time to compute 30020 pairs: 24362.11968421936 s
# 30020
# ## Completed 7.235176548967355% ##
# ## Current frame2172.0 ##
# Estimated time to compute 30020 pairs: 123558.95864069462 s
# 30020
# ## Completed 7.261825449700201% ##
# ## Current frame2180.0 ##
# Estimated time to compute 30020 pairs: 29204.064865112305 s
# 30020
# ## Completed 7.288474350433044% ##
# ## Current frame2188.0 ##
# Estimated time to compute 30020 pairs: 20869.232887625694 s
# 30020
# ## Completed 7.31512325116589% ##
# ## Current frame2196.0 ##
# Estimated time to compute 30020 pairs: 71200.15142321587 s
# 30020
# ## Completed 7.328447701532312% ##
# ## Current frame2200.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 44043.692777752876 s
# 30020
# ## Completed 7.355096602265157% ##
# ## Current frame2208.0 ##
# Estimated time to compute 30020 pairs: 28227.519340515137 s
# 30020
# ## Completed 7.381745502998001% ##
# ## Current frame2216.0 ##
# Estimated time to compute 30020 pairs: 5444688.142211437 s
# 30020
# ## Completed 7.4083944037308465% ##
# ## Current frame2224.0 ##
# Estimated time to compute 30020 pairs: 96746.82820081711 s
# 30020
# ## Completed 7.435043304463691% ##
# ## Current frame2232.0 ##
# Estimated time to compute 30020 pairs: 33739.31953251362 s
# 30020
# ## Completed 7.461692205196535% ##
# ## Current frame2240.0 ##
# Estimated time to compute 30020 pairs: 31250.601064562798 s
# 30020
# ## Completed 7.48834110592938% ##
# ## Current frame2248.0 ##
# Estimated time to compute 30020 pairs: 31844.781670570374 s
# 30020
# ## Completed 7.5149900066622255% ##
# ## Current frame2256.0 ##
# Estimated time to compute 30020 pairs: 25304.998043179512 s
# 30020
# ## Completed 7.541638907395069% ##
# ## Current frame2264.0 ##
# Estimated time to compute 30020 pairs: 25152.03704535961 s
# 30020
# ## Completed 7.568287808127915% ##
# ## Current frame2272.0 ##
# Estimated time to compute 30020 pairs: 25141.15612089634 s
# 30020
# ## Completed 7.59493670886076% ##
# ## Current frame2280.0 ##
# Estimated time to compute 30020 pairs: 35272.011634111404 s
# 30020
# ## Completed 7.6215856095936045% ##
# ## Current frame2288.0 ##
# Estimated time to compute 30020 pairs: 32804.80361402035 s
# 30020
# ## Completed 7.648234510326449% ##
# ## Current frame2296.0 ##
# Estimated time to compute 30020 pairs: 31783.679580688477 s
# 30020
# ## Completed 7.661558960692871% ##
# ## Current frame2300.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 33073.75444352627 s
# 30020
# ## Completed 7.688207861425717% ##
# ## Current frame2308.0 ##
# Estimated time to compute 30020 pairs: 25192.51977443695 s
# 30020
# ## Completed 7.71485676215856% ##
# ## Current frame2316.0 ##
# Estimated time to compute 30020 pairs: 20072.922245264053 s
# 30020
# ## Completed 7.741505662891406% ##
# ## Current frame2324.0 ##
# Estimated time to compute 30020 pairs: 21188.961364626884 s
# 30020
# ## Completed 7.76815456362425% ##
# ## Current frame2332.0 ##
# Estimated time to compute 30020 pairs: 18526.904992461205 s
# 30020
# ## Completed 7.794803464357095% ##
# ## Current frame2340.0 ##
# Estimated time to compute 30020 pairs: 19101.805552244186 s
# 30020
# ## Completed 7.8214523650899395% ##
# ## Current frame2348.0 ##
# Estimated time to compute 30020 pairs: 19819.531441926956 s
# 30020
# ## Completed 7.848101265822785% ##
# ## Current frame2356.0 ##
# Estimated time to compute 30020 pairs: 18920.305612683296 s
# 30020
# ## Completed 7.87475016655563% ##
# ## Current frame2364.0 ##
# Estimated time to compute 30020 pairs: 19947.619838118553 s
# 30020
# ## Completed 7.901399067288474% ##
# ## Current frame2372.0 ##
# Estimated time to compute 30020 pairs: 19309.974582195282 s
# 30020
# ## Completed 7.928047968021319% ##
# ## Current frame2380.0 ##
# Estimated time to compute 30020 pairs: 21056.90423130989 s
# 30020
# ## Completed 7.954696868754165% ##
# ## Current frame2388.0 ##
# Estimated time to compute 30020 pairs: 20435.000618696213 s
# 30020
# ## Completed 7.9813457694870085% ##
# ## Current frame2396.0 ##
# Estimated time to compute 30020 pairs: 22324.377154111862 s
# 30020
# ## Completed 7.994670219853431% ##
# ## Current frame2400.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 24648.65248441696 s
# 30020
# ## Completed 8.021319120586275% ##
# ## Current frame2408.0 ##
# Estimated time to compute 30020 pairs: 22199.50865983963 s
# 30020
# ## Completed 8.047968021319122% ##
# ## Current frame2416.0 ##
# Estimated time to compute 30020 pairs: 20826.738055348396 s
# 30020
# ## Completed 8.074616922051964% ##
# ## Current frame2424.0 ##
# Estimated time to compute 30020 pairs: 20702.53787636757 s
# 30020
# ## Completed 8.10126582278481% ##
# ## Current frame2432.0 ##
# Estimated time to compute 30020 pairs: 17754.94804561138 s
# 30020
# ## Completed 8.127914723517655% ##
# ## Current frame2440.0 ##
# Estimated time to compute 30020 pairs: 19957.913861870766 s
# 30020
# ## Completed 8.1545636242505% ##
# ## Current frame2448.0 ##
# Estimated time to compute 30020 pairs: 22800.405521392822 s
# 30020
# ## Completed 8.181212524983344% ##
# ## Current frame2456.0 ##
# Estimated time to compute 30020 pairs: 24869.901527166367 s
# 30020
# ## Completed 8.207861425716189% ##
# ## Current frame2464.0 ##
# Estimated time to compute 30020 pairs: 33041.091092824936 s
# 30020
# ## Completed 8.234510326449033% ##
# ## Current frame2472.0 ##
# Estimated time to compute 30020 pairs: 22110.829393863678 s
# 30020
# ## Completed 8.261159227181878% ##
# ## Current frame2480.0 ##
# Estimated time to compute 30020 pairs: 22229.711679816246 s
# 30020
# ## Completed 8.287808127914724% ##
# ## Current frame2488.0 ##
# Estimated time to compute 30020 pairs: 19938.70002090931 s
# 30020
# ## Completed 8.314457028647567% ##
# ## Current frame2496.0 ##
# Estimated time to compute 30020 pairs: 18147.911174297333 s
# 30020
# ## Completed 8.327781479013991% ##
# ## Current frame2500.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 19321.492508649826 s
# 30020
# ## Completed 8.354430379746836% ##
# ## Current frame2508.0 ##
# Estimated time to compute 30020 pairs: 22295.9187322855 s
# 30020
# ## Completed 8.38107928047968% ##
# ## Current frame2516.0 ##
# Estimated time to compute 30020 pairs: 19303.443522453308 s
# 30020
# ## Completed 8.407728181212525% ##
# ## Current frame2524.0 ##
# Estimated time to compute 30020 pairs: 24921.624836325645 s
# 30020
# ## Completed 8.43437708194537% ##
# ## Current frame2532.0 ##
# Estimated time to compute 30020 pairs: 21333.15284907818 s
# 30020
# ## Completed 8.461025982678215% ##
# ## Current frame2540.0 ##
# Estimated time to compute 30020 pairs: 18012.45431125164 s
# 30020
# ## Completed 8.487674883411058% ##
# ## Current frame2548.0 ##
# Estimated time to compute 30020 pairs: 18208.502410054207 s
# 30020
# ## Completed 8.514323784143905% ##
# ## Current frame2556.0 ##
# Estimated time to compute 30020 pairs: 19194.268359541893 s
# 30020
# ## Completed 8.540972684876749% ##
# ## Current frame2564.0 ##
# Estimated time to compute 30020 pairs: 19120.563113689423 s
# 30020
# ## Completed 8.567621585609594% ##
# ## Current frame2572.0 ##
# Estimated time to compute 30020 pairs: 19409.135751724243 s
# 30020
# ## Completed 8.594270486342438% ##
# ## Current frame2580.0 ##
# Estimated time to compute 30020 pairs: 18499.427124261856 s
# 30020
# ## Completed 8.620919387075283% ##
# ## Current frame2588.0 ##
# Estimated time to compute 30020 pairs: 18262.949976325035 s
# 30020
# ## Completed 8.647568287808127% ##
# ## Current frame2596.0 ##
# Estimated time to compute 30020 pairs: 21742.55814433098 s
# 30020
# ## Completed 8.66089273817455% ##
# ## Current frame2600.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 19036.394752264023 s
# 30020
# ## Completed 8.687541638907396% ##
# ## Current frame2608.0 ##
# Estimated time to compute 30020 pairs: 19644.685131311417 s
# 30020
# ## Completed 8.71419053964024% ##
# ## Current frame2616.0 ##
# Estimated time to compute 30020 pairs: 20725.66587984562 s
# 30020
# ## Completed 8.740839440373085% ##
# ## Current frame2624.0 ##
# Estimated time to compute 30020 pairs: 22067.06324160099 s
# 30020
# ## Completed 8.76748834110593% ##
# ## Current frame2632.0 ##
# Estimated time to compute 30020 pairs: 19907.504816651344 s
# 30020
# ## Completed 8.794137241838774% ##
# ## Current frame2640.0 ##
# Estimated time to compute 30020 pairs: 21967.56567776203 s
# 30020
# ## Completed 8.820786142571619% ##
# ## Current frame2648.0 ##
# Estimated time to compute 30020 pairs: 22359.41673696041 s
# 30020
# ## Completed 8.847435043304463% ##
# ## Current frame2656.0 ##
# Estimated time to compute 30020 pairs: 18646.70610010624 s
# 30020
# ## Completed 8.87408394403731% ##
# ## Current frame2664.0 ##
# Estimated time to compute 30020 pairs: 20088.752460479736 s
# 30020
# ## Completed 8.900732844770154% ##
# ## Current frame2672.0 ##
# Estimated time to compute 30020 pairs: 17800.20471096039 s
# 30020
# ## Completed 8.927381745502998% ##
# ## Current frame2680.0 ##
# Estimated time to compute 30020 pairs: 17289.864124059677 s
# 30020
# ## Completed 8.954030646235843% ##
# ## Current frame2688.0 ##
# Estimated time to compute 30020 pairs: 17962.506913542747 s
# 30020
# ## Completed 8.980679546968688% ##
# ## Current frame2696.0 ##
# Estimated time to compute 30020 pairs: 19793.96547436714 s
# 30020
# ## Completed 8.99400399733511% ##
# ## Current frame2700.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 21239.807901382446 s
# 30020
# ## Completed 9.020652898067954% ##
# ## Current frame2708.0 ##
# Estimated time to compute 30020 pairs: 25965.103881955147 s
# 30020
# ## Completed 9.047301798800799% ##
# ## Current frame2716.0 ##
# Estimated time to compute 30020 pairs: 20832.922879457474 s
# 30020
# ## Completed 9.073950699533643% ##
# ## Current frame2724.0 ##
# Estimated time to compute 30020 pairs: 22250.809686779976 s
# 30020
# ## Completed 9.100599600266488% ##
# ## Current frame2732.0 ##
# Estimated time to compute 30020 pairs: 20601.25724375248 s
# 30020
# ## Completed 9.127248500999334% ##
# ## Current frame2740.0 ##
# Estimated time to compute 30020 pairs: 20434.93709743023 s
# 30020
# ## Completed 9.153897401732179% ##
# ## Current frame2748.0 ##
# Estimated time to compute 30020 pairs: 21485.520683526993 s
# 30020
# ## Completed 9.180546302465023% ##
# ## Current frame2756.0 ##
# Estimated time to compute 30020 pairs: 22878.282593488693 s
# 30020
# ## Completed 9.207195203197868% ##
# ## Current frame2764.0 ##
# Estimated time to compute 30020 pairs: 21778.35998237133 s
# 30020
# ## Completed 9.233844103930714% ##
# ## Current frame2772.0 ##
# Estimated time to compute 30020 pairs: 23651.664742827415 s
# 30020
# ## Completed 9.260493004663557% ##
# ## Current frame2780.0 ##
# Estimated time to compute 30020 pairs: 21361.8814599514 s
# 30020
# ## Completed 9.287141905396403% ##
# ## Current frame2788.0 ##
# Estimated time to compute 30020 pairs: 21275.872771143913 s
# 30020
# ## Completed 9.313790806129248% ##
# ## Current frame2796.0 ##
# Estimated time to compute 30020 pairs: 24729.923918247223 s
# 30020
# ## Completed 9.327115256495668% ##
# ## Current frame2800.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 25983.88112604618 s
# 30020
# ## Completed 9.353764157228515% ##
# ## Current frame2808.0 ##
# Estimated time to compute 30020 pairs: 26315.573073029518 s
# 30020
# ## Completed 9.38041305796136% ##
# ## Current frame2816.0 ##
# Estimated time to compute 30020 pairs: 24775.737065672874 s
# 30020
# ## Completed 9.407061958694204% ##
# ## Current frame2824.0 ##
# Estimated time to compute 30020 pairs: 32396.266144514084 s
# 30020
# ## Completed 9.433710859427048% ##
# ## Current frame2832.0 ##
# Estimated time to compute 30020 pairs: 28130.238758325577 s
# 30020
# ## Completed 9.460359760159893% ##
# ## Current frame2840.0 ##
# ...
# ## Current frame14988.0 ##
# Estimated time to compute 30020 pairs: 11707.148253917694 s
# 30020
# ## Completed 49.953364423717524% ##
# ## Current frame14996.0 ##
# Estimated time to compute 30020 pairs: 12690.550496578217 s
# 30020
# ## Completed 49.96668887408394% ##
# ## Current frame15000.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 12994.690318107605 s
# 30020
# ## Completed 49.99333777481679% ##
# ## Current frame15008.0 ##
# Estimated time to compute 30020 pairs: 12810.199511051178 s
# 30020
# ## Completed 50.01998667554963% ##
# ## Current frame15016.0 ##
# Estimated time to compute 30020 pairs: 12516.311663985252 s
# 30020
# ## Completed 50.04663557628248% ##
# ## Current frame15024.0 ##
# Estimated time to compute 30020 pairs: 11801.058630347252 s
# 30020
# ## Completed 50.07328447701532% ##
# ## Current frame15032.0 ##
# Estimated time to compute 30020 pairs: 12293.47369492054 s
# 30020
# ## Completed 50.099933377748165% ##
# ## Current frame15040.0 ##
# Estimated time to compute 30020 pairs: 12135.989267230034 s
# 30020
# ## Completed 50.12658227848101% ##
# ## Current frame15048.0 ##
# Estimated time to compute 30020 pairs: 12463.436920046806 s
# 30020
# ## Completed 50.153231179213854% ##
# ## Current frame15056.0 ##
# Estimated time to compute 30020 pairs: 12579.850823283195 s
# 30020
# ## Completed 50.179880079946706% ##
# ## Current frame15064.0 ##
# Estimated time to compute 30020 pairs: 13876.94612801075 s
# 30020
# ## Completed 50.20652898067954% ##
# ## Current frame15072.0 ##
# Estimated time to compute 30020 pairs: 12000.060020685196 s
# 30020
# ## Completed 50.233177881412395% ##
# ## Current frame15080.0 ##
# Estimated time to compute 30020 pairs: 12265.42413532734 s
# 30020
# ## Completed 50.25982678214523% ##
# ## Current frame15088.0 ##
# Estimated time to compute 30020 pairs: 11703.846937417984 s
# 30020
# ## Completed 50.286475682878084% ##
# ## Current frame15096.0 ##
# Estimated time to compute 30020 pairs: 12714.148199558258 s
# 30020
# ## Completed 50.299800133244496% ##
# ## Current frame15100.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 13041.030423641205 s
# 30020
# ## Completed 50.32644903397735% ##
# ## Current frame15108.0 ##
# Estimated time to compute 30020 pairs: 12133.120074272156 s
# 30020
# ## Completed 50.35309793471019% ##
# ## Current frame15116.0 ##
# Estimated time to compute 30020 pairs: 12315.873440504074 s
# 30020
# ## Completed 50.37974683544304% ##
# ## Current frame15124.0 ##
# Estimated time to compute 30020 pairs: 11865.785905718803 s
# 30020
# ## Completed 50.40639573617588% ##
# ## Current frame15132.0 ##
# Estimated time to compute 30020 pairs: 12374.539355635643 s
# 30020
# ## Completed 50.43304463690873% ##
# ## Current frame15140.0 ##
# Estimated time to compute 30020 pairs: 12147.972419857979 s
# 30020
# ## Completed 50.45969353764157% ##
# ## Current frame15148.0 ##
# Estimated time to compute 30020 pairs: 11961.75938129425 s
# 30020
# ## Completed 50.48634243837442% ##
# ## Current frame15156.0 ##
# Estimated time to compute 30020 pairs: 11955.639867782593 s
# 30020
# ## Completed 50.51299133910726% ##
# ## Current frame15164.0 ##
# Estimated time to compute 30020 pairs: 12318.379399180412 s
# 30020
# ## Completed 50.53964023984011% ##
# ## Current frame15172.0 ##
# Estimated time to compute 30020 pairs: 12002.011286616325 s
# 30020
# ## Completed 50.56628914057295% ##
# ## Current frame15180.0 ##
# Estimated time to compute 30020 pairs: 11787.763003110886 s
# 30020
# ## Completed 50.5929380413058% ##
# ## Current frame15188.0 ##
# Estimated time to compute 30020 pairs: 11552.170679569244 s
# 30020
# ## Completed 50.619586942038644% ##
# ## Current frame15196.0 ##
# Estimated time to compute 30020 pairs: 12906.977291107178 s
# 30020
# ## Completed 50.63291139240506% ##
# ## Current frame15200.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 12629.341941475868 s
# 30020
# ## Completed 50.65956029313791% ##
# ## Current frame15208.0 ##
# Estimated time to compute 30020 pairs: 12426.097151637077 s
# 30020
# ## Completed 50.68620919387076% ##
# ## Current frame15216.0 ##
# Estimated time to compute 30020 pairs: 11765.822221040726 s
# 30020
# ## Completed 50.7128580946036% ##
# ## Current frame15224.0 ##
# Estimated time to compute 30020 pairs: 12048.239558935165 s
# 30020
# ## Completed 50.73950699533645% ##
# ## Current frame15232.0 ##
# Estimated time to compute 30020 pairs: 11862.37007200718 s
# 30020
# ## Completed 50.766155896069286% ##
# ## Current frame15240.0 ##
# Estimated time to compute 30020 pairs: 12161.956045031548 s
# 30020
# ## Completed 50.79280479680213% ##
# ## Current frame15248.0 ##
# Estimated time to compute 30020 pairs: 11970.357118844986 s
# 30020
# ## Completed 50.819453697534975% ##
# ## Current frame15256.0 ##
# Estimated time to compute 30020 pairs: 12408.002537488937 s
# 30020
# ## Completed 50.84610259826782% ##
# ## Current frame15264.0 ##
# Estimated time to compute 30020 pairs: 12167.901993393898 s
# 30020
# ## Completed 50.87275149900067% ##
# ## Current frame15272.0 ##
# Estimated time to compute 30020 pairs: 12181.551013588905 s
# 30020
# ## Completed 50.89940039973351% ##
# ## Current frame15280.0 ##
# Estimated time to compute 30020 pairs: 12467.538067698479 s
# 30020
# ## Completed 50.92604930046636% ##
# ## Current frame15288.0 ##
# Estimated time to compute 30020 pairs: 12181.95361316204 s
# 30020
# ## Completed 50.9526982011992% ##
# ## Current frame15296.0 ##
# Estimated time to compute 30020 pairs: 12473.547537326813 s
# 30020
# ## Completed 50.96602265156562% ##
# ## Current frame15300.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 12964.031913280487 s
# 30020
# ## Completed 50.99267155229846% ##
# ## Current frame15308.0 ##
# Estimated time to compute 30020 pairs: 12134.614166021347 s
# 30020
# ## Completed 51.01932045303131% ##
# ## Current frame15316.0 ##
# Estimated time to compute 30020 pairs: 11791.143944859505 s
# 30020
# ## Completed 51.04596935376415% ##
# ## Current frame15324.0 ##
# Estimated time to compute 30020 pairs: 12155.946575403214 s
# 30020
# ## Completed 51.072618254497% ##
# ## Current frame15332.0 ##
# Estimated time to compute 30020 pairs: 11777.68012046814 s
# 30020
# ## Completed 51.099267155229846% ##
# ## Current frame15340.0 ##
# Estimated time to compute 30020 pairs: 12010.067751407623 s
# 30020
# ## Completed 51.1259160559627% ##
# ## Current frame15348.0 ##
# Estimated time to compute 30020 pairs: 12030.465235114098 s
# 30020
# ## Completed 51.152564956695535% ##
# ## Current frame15356.0 ##
# Estimated time to compute 30020 pairs: 11881.90778195858 s
# 30020
# ## Completed 51.17921385742839% ##
# ## Current frame15364.0 ##
# Estimated time to compute 30020 pairs: 12392.760117650032 s
# 30020
# ## Completed 51.205862758161224% ##
# ## Current frame15372.0 ##
# Estimated time to compute 30020 pairs: 12262.528997063637 s
# 30020
# ## Completed 51.232511658894076% ##
# ## Current frame15380.0 ##
# Estimated time to compute 30020 pairs: 11671.856375336647 s
# 30020
# ## Completed 51.25916055962691% ##
# ## Current frame15388.0 ##
# Estimated time to compute 30020 pairs: 11872.609521150589 s
# 30020
# ## Completed 51.28580946035976% ##
# ## Current frame15396.0 ##
# Estimated time to compute 30020 pairs: 12551.927411556244 s
# 30020
# ## Completed 51.299133910726184% ##
# ## Current frame15400.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 14238.107469081879 s
# 30020
# ## Completed 51.32578281145903% ##
# ## Current frame15408.0 ##
# Estimated time to compute 30020 pairs: 22842.911089658737 s
# 30020
# ## Completed 51.35243171219187% ##
# ## Current frame15416.0 ##
# Estimated time to compute 30020 pairs: 29629.083866477013 s
# 30020
# ## Completed 51.379080612924724% ##
# ## Current frame15424.0 ##
# Estimated time to compute 30020 pairs: 28060.259795188904 s
# 30020
# ## Completed 51.40572951365756% ##
# ## Current frame15432.0 ##
# Estimated time to compute 30020 pairs: 29702.671911120415 s
# 30020
# ## Completed 51.43237841439041% ##
# ## Current frame15440.0 ##
# Estimated time to compute 30020 pairs: 30291.807497143745 s
# 30020
# ## Completed 51.45902731512325% ##
# ## Current frame15448.0 ##
# Estimated time to compute 30020 pairs: 27668.49372923374 s
# 30020
# ## Completed 51.48567621585609% ##
# ## Current frame15456.0 ##
# Estimated time to compute 30020 pairs: 29092.266542315483 s
# 30020
# ## Completed 51.51232511658894% ##
# ## Current frame15464.0 ##
# Estimated time to compute 30020 pairs: 28068.724227547646 s
# 30020
# ## Completed 51.538974017321785% ##
# ## Current frame15472.0 ##
# Estimated time to compute 30020 pairs: 28939.09708738327 s
# 30020
# ## Completed 51.56562291805463% ##
# ## Current frame15480.0 ##
# Estimated time to compute 30020 pairs: 29359.936210513115 s
# 30020
# ## Completed 51.592271818787474% ##
# ## Current frame15488.0 ##
# Estimated time to compute 30020 pairs: 27656.89080953598 s
# 30020
# ## Completed 51.618920719520325% ##
# ## Current frame15496.0 ##
# Estimated time to compute 30020 pairs: 29863.277827501297 s
# 30020
# ## Completed 51.63224516988674% ##
# ## Current frame15500.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 31210.321424603462 s
# 30020
# ## Completed 51.65889407061959% ##
# ## Current frame15508.0 ##
# Estimated time to compute 30020 pairs: 29028.232632875443 s
# 30020
# ## Completed 51.685542971352426% ##
# ## Current frame15516.0 ##
# Estimated time to compute 30020 pairs: 29332.038744091988 s
# 30020
# ## Completed 51.71219187208528% ##
# ## Current frame15524.0 ##
# Estimated time to compute 30020 pairs: 28948.667326569557 s
# 30020
# ## Completed 51.738840772818115% ##
# ## Current frame15532.0 ##
# Estimated time to compute 30020 pairs: 30153.32487463951 s
# 30020
# ## Completed 51.76548967355097% ##
# ## Current frame15540.0 ##
# Estimated time to compute 30020 pairs: 27817.342843413353 s
# 30020
# ## Completed 51.79213857428381% ##
# ## Current frame15548.0 ##
# Estimated time to compute 30020 pairs: 29088.707562088966 s
# 30020
# ## Completed 51.818787475016656% ##
# ## Current frame15556.0 ##
# Estimated time to compute 30020 pairs: 28147.410972118378 s
# 30020
# ## Completed 51.8454363757495% ##
# ## Current frame15564.0 ##
# Estimated time to compute 30020 pairs: 29316.47692859173 s
# 30020
# ## Completed 51.87208527648235% ##
# ## Current frame15572.0 ##
# Estimated time to compute 30020 pairs: 27981.409326791763 s
# 30020
# ## Completed 51.89873417721519% ##
# ## Current frame15580.0 ##
# Estimated time to compute 30020 pairs: 27704.840418696404 s
# 30020
# ## Completed 51.92538307794804% ##
# ## Current frame15588.0 ##
# Estimated time to compute 30020 pairs: 26974.853135347366 s
# 30020
# ## Completed 51.95203197868088% ##
# ## Current frame15596.0 ##
# Estimated time to compute 30020 pairs: 29662.836920022964 s
# 30020
# ## Completed 51.965356429047304% ##
# ## Current frame15600.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 29772.20712006092 s
# 30020
# ## Completed 51.99200532978014% ##
# ## Current frame15608.0 ##
# Estimated time to compute 30020 pairs: 27989.928333759308 s
# 30020
# ## Completed 52.01865423051299% ##
# ## Current frame15616.0 ##
# Estimated time to compute 30020 pairs: 28943.943491578102 s
# 30020
# ## Completed 52.04530313124584% ##
# ## Current frame15624.0 ##
# Estimated time to compute 30020 pairs: 28143.55943620205 s
# 30020
# ## Completed 52.07195203197868% ##
# ## Current frame15632.0 ##
# Estimated time to compute 30020 pairs: 28886.64283633232 s
# 30020
# ## Completed 52.09860093271153% ##
# ## Current frame15640.0 ##
# Estimated time to compute 30020 pairs: 28302.58716225624 s
# 30020
# ## Completed 52.12524983344438% ##
# ## Current frame15648.0 ##
# Estimated time to compute 30020 pairs: 27292.459465265274 s
# 30020
# ## Completed 52.151898734177216% ##
# ## Current frame15656.0 ##
# Estimated time to compute 30020 pairs: 29052.562172412872 s
# 30020
# ## Completed 52.17854763491005% ##
# ## Current frame15664.0 ##
# Estimated time to compute 30020 pairs: 28348.13996195793 s
# 30020
# ## Completed 52.205196535642905% ##
# ## Current frame15672.0 ##
# Estimated time to compute 30020 pairs: 30040.155923962593 s
# 30020
# ## Completed 52.23184543637574% ##
# ## Current frame15680.0 ##
# Estimated time to compute 30020 pairs: 33731.480471491814 s
# 30020
# ## Completed 52.258494337108594% ##
# ## Current frame15688.0 ##
# Estimated time to compute 30020 pairs: 28623.273826241493 s
# 30020
# ## Completed 52.28514323784144% ##
# ## Current frame15696.0 ##
# Estimated time to compute 30020 pairs: 28984.610521793365 s
# 30020
# ## Completed 52.298467688207865% ##
# ## Current frame15700.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 28923.104937672615 s
# 30020
# ## Completed 52.3251165889407% ##
# ## Current frame15708.0 ##
# Estimated time to compute 30020 pairs: 29745.798377394676 s
# 30020
# ## Completed 52.351765489673554% ##
# ## Current frame15716.0 ##
# Estimated time to compute 30020 pairs: 28100.569853782654 s
# 30020
# ## Completed 52.37841439040639% ##
# ## Current frame15724.0 ##
# Estimated time to compute 30020 pairs: 27169.800795316696 s
# 30020
# ## Completed 52.40506329113924% ##
# ## Current frame15732.0 ##
# Estimated time to compute 30020 pairs: 28015.675918459892 s
# 30020
# ## Completed 52.43171219187208% ##
# ## Current frame15740.0 ##
# Estimated time to compute 30020 pairs: 29811.105396151543 s
# 30020
# ## Completed 52.45836109260493% ##
# ## Current frame15748.0 ##
# Estimated time to compute 30020 pairs: 29616.42971456051 s
# 30020
# ## Completed 52.48500999333777% ##
# ## Current frame15756.0 ##
# Estimated time to compute 30020 pairs: 27765.05857884884 s
# 30020
# ## Completed 52.51165889407062% ##
# ## Current frame15764.0 ##
# Estimated time to compute 30020 pairs: 27805.64777314663 s
# 30020
# ## Completed 52.538307794803465% ##
# ## Current frame15772.0 ##
# Estimated time to compute 30020 pairs: 29073.247738480568 s
# 30020
# ## Completed 52.56495669553631% ##
# ## Current frame15780.0 ##
# Estimated time to compute 30020 pairs: 29360.509691238403 s
# 30020
# ## Completed 52.591605596269154% ##
# ## Current frame15788.0 ##
# Estimated time to compute 30020 pairs: 30166.606187224388 s
# 30020
# ## Completed 52.618254497002006% ##
# ## Current frame15796.0 ##
# Estimated time to compute 30020 pairs: 30642.986158132553 s
# 30020
# ## Completed 52.63157894736842% ##
# ## Current frame15800.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 31285.94125509262 s
# 30020
# ## Completed 52.65822784810127% ##
# ## Current frame15808.0 ##
# Estimated time to compute 30020 pairs: 28134.067927598953 s
# 30020
# ## Completed 52.68487674883411% ##
# ## Current frame15816.0 ##
# Estimated time to compute 30020 pairs: 27784.63833808899 s
# 30020
# ## Completed 52.71152564956696% ##
# ## Current frame15824.0 ##
# Estimated time to compute 30020 pairs: 28232.07587301731 s
# 30020
# ## Completed 52.738174550299796% ##
# ## Current frame15832.0 ##
# Estimated time to compute 30020 pairs: 29178.7368786335 s
# 30020
# ## Completed 52.76482345103265% ##
# ## Current frame15840.0 ##
# Estimated time to compute 30020 pairs: 29125.573157668114 s
# 30020
# ## Completed 52.79147235176549% ##
# ## Current frame15848.0 ##
# Estimated time to compute 30020 pairs: 27517.956380844116 s
# 30020
# ## Completed 52.81812125249833% ##
# ## Current frame15856.0 ##
# Estimated time to compute 30020 pairs: 27564.43873822689 s
# 30020
# ## Completed 52.84477015323118% ##
# ## Current frame15864.0 ##
# Estimated time to compute 30020 pairs: 29060.435230731964 s
# 30020
# ## Completed 52.87141905396402% ##
# ## Current frame15872.0 ##
# Estimated time to compute 30020 pairs: 27669.098523259163 s
# 30020
# ## Completed 52.89806795469687% ##
# ## Current frame15880.0 ##
# Estimated time to compute 30020 pairs: 27034.882521033287 s
# 30020
# ## Completed 52.92471685542971% ##
# ## Current frame15888.0 ##
# Estimated time to compute 30020 pairs: 26398.94339263439 s
# 30020
# ## Completed 52.95136575616256% ##
# ## Current frame15896.0 ##
# Estimated time to compute 30020 pairs: 30665.436899662018 s
# 30020
# ## Completed 52.964690206528985% ##
# ## Current frame15900.0 ##
# write to file
# sucessfully written
# Estimated time to compute 30020 pairs: 31430.599755048752 s
# 30020
# ## Completed 52.99133910726182% ##
# ## Current frame15908.0 ##
# Estimated time to compute 30020 pairs: 35872.99975156784 s
# 30020
# ## Completed 53.01798800799467% ##
# ## Current frame15916.0 ##
